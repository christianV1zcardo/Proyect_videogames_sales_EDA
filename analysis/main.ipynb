# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('videogames-sales-dataset/Video_Games_Sales_as_at_22_Dec_2016.csv',
                 encoding='latin1')

# %%
df.head(20)
# Out:
#                                             Name Platform  Year_of_Release  \
# 0                                     Wii Sports      Wii           2006.0
# 1                              Super Mario Bros.      NES           1985.0
# 2                                 Mario Kart Wii      Wii           2008.0
# 3                              Wii Sports Resort      Wii           2009.0
# 4                       Pokemon Red/Pokemon Blue       GB           1996.0
# 5                                         Tetris       GB           1989.0
# 6                          New Super Mario Bros.       DS           2006.0
# 7                                       Wii Play      Wii           2006.0
# 8                      New Super Mario Bros. Wii      Wii           2009.0
# 9                                      Duck Hunt      NES           1984.0
# 10                                    Nintendogs       DS           2005.0
# ...

# %%
df.describe().transpose()
# Out:
#                    count         mean         std      min      25%      50%  \
# Year_of_Release  16450.0  2006.487356    5.878995  1980.00  2003.00  2007.00
# NA_Sales         16719.0     0.263330    0.813514     0.00     0.00     0.08
# EU_Sales         16719.0     0.145025    0.503283     0.00     0.00     0.02
# JP_Sales         16719.0     0.077602    0.308818     0.00     0.00     0.00
# Other_Sales      16719.0     0.047332    0.186710     0.00     0.00     0.01
# Global_Sales     16719.0     0.533543    1.547935     0.01     0.06     0.17
# Critic_Score      8137.0    68.967679   13.938165    13.00    60.00    71.00
# Critic_Count      8137.0    26.360821   18.980495     3.00    12.00    21.00
# User_Score        7590.0     7.125046    1.500006     0.00     6.40     7.50
# User_Count        7590.0   162.229908  561.282326     4.00    10.00    24.00
#
#                      75%       max
# Year_of_Release  2010.00   2020.00
# NA_Sales            0.24     41.36
# ...

# %%
df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
# Limpieza de Datos

df = df.rename(columns={'Year_of_Release':'Year', 
                        'Critic_Score':'Staff_Score',
                        'Critic_Count': 'Staff_Count'})

df = df.dropna(subset=['Year'])

df = df.fillna({
    'Name':'Unknown', 
    'Developer':'Unknown',
    'Genre': df['Genre'].mode()[0],
    'Publisher': df['Publisher'].mode()[0],
    'Rating': 'No clasificado',
    'Staff_Score' : df['Staff_Score'].median(),
    'Staff_Count': df['Staff_Count'].median(),
    'User_Score': df.User_Score.median(),
    'User_Count': df.User_Count.median()
})

df['Year'] = df['Year'].astype(int)
df['Staff_Score'] = df['Staff_Score'] / 10


df.isnull().sum()
# Out:
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# Staff_Score     0
# Staff_Count     0
# User_Score      0
# User_Count      0
# Developer       0
# Rating          0
# dtype: int64

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,10))

fig.suptitle('Principales Distribuciones', fontweight='bold')
ax = ax.flatten()

it1 = ['Genre', 'Platform', 'Rating']

sns.histplot(data=df, x='Year', ax=ax[0], bins=15, kde=True, color='green', 
            edgecolor='white', linewidth=1.5)
ax[0].set_xlabel('')
ax[0].set_ylabel('')
ax[0].set_title(f'Distribución de Juegos por Year')

for i, x in enumerate(it1):
    graf = df[x].value_counts().reset_index()
    
    i += 1
    sns.barplot(data=graf, y=x, x='count', ax=ax[i], color='forestgreen')
    ax[i].set_xlabel('')
    ax[i].set_ylabel('')
    ax[i].set_title(f'Distribución de Juegos por {x}')    

plt.tight_layout()
plt.show()

# %%
# TOP 10 JUEGOS POR CONSOLA
fig, ax = plt.subplots(nrows=6, ncols=2, figsize=(12,17))
fig.suptitle('Top 10 Juegos por Consola (por ventas en millones)', 
             fontweight='bold', y=1.005 )
ax = ax.flatten()

# Lista de top 10 consolas en ventas
top_10_p = df.groupby('Platform')['Global_Sales'].sum() \
    .sort_values(ascending=False)[:12].index

for i, console in enumerate(top_10_p):
    # Lista de top 10 juegos por consola
    top_10_j = df[df['Platform'] == console] \
        .sort_values(by='Global_Sales', ascending=False)\
            [['Name', 'Global_Sales']][:10]
            
    # Gráfico
    sns.barplot(data=top_10_j, y='Name', x='Global_Sales', ax=ax[i], 
                palette='RdBu_r', hue='Name')
    ax[i].set_title(console)
    ax[i].set_xlabel('')
    ax[i].set_ylabel('')
    
plt.tight_layout()
plt.show()

# %%
fig, ax  = plt.subplots(nrows=6,  ncols=2, figsize=(12, 17))
fig.suptitle('Top 10 Juegos por Año (por ventas en millones)',
             fontweight='bold', y=1.005)
ax = ax.flatten()

# Top Años por Ventas
top_y = df.groupby('Year')['Global_Sales'].sum().sort_values(ascending=False)\
    [:12].index

for i, year in enumerate(top_y):        
    # Top Juegos por Años
    top_j = df[df['Year'] == year][['Name', 'Global_Sales']] \
    .sort_values(by='Global_Sales', ascending=False)[:10]
    # Gráfico
    sns.barplot(data=top_j, y='Name', x='Global_Sales', ax=ax[i], 
            palette='RdBu_r', hue='Name')
    ax[i].set_title(year)
    ax[i].set_xlabel('')
    ax[i].set_ylabel('')

plt.tight_layout()
plt.show()

# %%
fig, ax  = plt.subplots(nrows=6,  ncols=2, figsize=(12, 17))
fig.suptitle('Top 10 Juegos por Género (por ventas en millones)',
             fontweight='bold', y=1.005)
ax = ax.flatten()

# Todos los Genres
gen = df['Genre'].unique()

for i, genre in enumerate(gen):        
    # Top Juegos por Años
    top_j = df[df['Genre'] == genre][['Name', 'Global_Sales']] \
    .sort_values(by='Global_Sales', ascending=False)[:10]
    # Gráfico
    sns.barplot(data=top_j, y='Name', x='Global_Sales', ax=ax[i], 
            palette='RdBu_r', hue='Name')
    ax[i].set_title(genre)
    ax[i].set_xlabel('')
    ax[i].set_ylabel('')

plt.tight_layout()
plt.show()

# %%
fig, ax  = plt.subplots(nrows=6,  ncols=2, figsize=(12, 17))
fig.suptitle('Top 10 Juegos por Publisher (por ventas en millones)',
             fontweight='bold', y=1.005)
ax = ax.flatten()

# Top Publishers por Ventas
top_p = df.groupby('Publisher')['Global_Sales'].sum() \
    .sort_values(ascending=False)[:12].index

for i, pub in enumerate(top_p):        
    # Top Juegos por Años
    top_j = df[df['Publisher'] == pub][['Name', 'Global_Sales']] \
    .sort_values(by='Global_Sales', ascending=False)[:10]
    # Gráfico
    sns.barplot(data=top_j, y='Name', x='Global_Sales', ax=ax[i], 
            palette='RdBu_r', hue='Name')
    ax[i].set_title(pub)
    ax[i].set_xlabel('')
    ax[i].set_ylabel('')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(8,6))

fig.suptitle('Top 10 Consolas con más Juegos vendidos por Region (en millones)'
            , fontweight='bold')
ax = ax.flatten()

regions = ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']
names = ['Norteamérica', 'Europa', 'Japón', 'Otros']

for i, x in enumerate(regions):
    top_j_r = df.groupby('Platform')[x].sum() \
        .sort_values(ascending=False)[:10]
    sns.barplot(data=top_j_r, ax=ax[i], palette='BrBG_r')
    ax[i].set_xlabel('')
    ax[i].set_ylabel('Ventas de Juegos')
    ax[i].set_title(names[i])
    ax[i].tick_params(axis='x', rotation=30)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\ACER NITRO\AppData\Local\Temp\ipykernel_19168\2761642989.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_j_r, ax=ax[i], palette='BrBG_r')
# C:\Users\ACER NITRO\AppData\Local\Temp\ipykernel_19168\2761642989.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_j_r, ax=ax[i], palette='BrBG_r')
# C:\Users\ACER NITRO\AppData\Local\Temp\ipykernel_19168\2761642989.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_j_r, ax=ax[i], palette='BrBG_r')
# ...

# %%
df_pp1 = df[['Staff_Score', 'User_Score', 'Staff_Count', 'User_Count']]

x = sns.pairplot(df_pp1, diag_kind='kde', 
            plot_kws={'color':"#3A86DD", 'alpha':0.3})

x.fig.suptitle('Relación entre Cuenta y Calificación del Staff y sus Usuarios \
(MetaStaff)', fontweight='bold')

plt.tight_layout()
plt.show()

# %%
df_pp1 = df[['Year', 'Staff_Score', 'User_Score', 
             'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]

df_pp1 = pd.melt(
    df_pp1, 
    id_vars=['Year', 'Staff_Score', 'User_Score'],
    value_vars=['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales'],
    var_name='Region',
    value_name='Sales')

x = sns.pairplot(df_pp1, diag_kind='kde', palette='viridis', hue='Region', 
            plot_kws={'alpha':0.3})

x.fig.suptitle('Relación entre Year, User Score, Staff Score y Sales',
               fontweight='bold', y=1.0005)

x._legend.set_bbox_to_anchor((1.02, 0.5)) 
x._legend.set_loc('center left') 

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(9,15))
fig.suptitle('Genre, Rating y Platform por Staff y User Scores', 
             fontweight='bold', y=1.003)
ax = ax.flatten()

it = ['Genre', 'Rating', 'Platform']#, 'Publisher']
it2 = ['Staff_Score', 'User_Score']
i = 0

for cat in it:
    for con in it2:
        df_it = df[[cat, *it2]]
        graf = sns.stripplot(data=df_it, x=con, y=cat, ax=ax[i], alpha=0.3,
                            color="#299C83")
        ax[i].set_xlabel('')
        ax[i].set_ylabel('')
        ax[i].set_title(f'{cat} por {con}')
        
        i += 1
    
plt.tight_layout()
plt.show()
